# %%
# !pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 tf_bodypix opencv-python tfjs_graph_converter matplotlib

# %%
import tensorflow as tf
from tf_bodypix.api import download_model, load_model, BodyPixModelPaths
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
load_model(download_model(BodyPixModelPaths.MOBILENET_FLOAT_50_STRIDE_16))

# %%
bodypix_model = load_model(download_model(BodyPixModelPaths.MOBILENET_FLOAT_50_STRIDE_16))

# %%
# get vid cap device
cap = cv2.VideoCapture(0) 

# loop through frame
while cap.isOpened(): 
    ret, frame = cap.read()
    
    result = bodypix_model.predict_single(frame)
    mask = result.get_mask(threshold=0.4).numpy().astype(np.uint8)
    masked_image = cv2.bitwise_and(frame, frame, mask=mask)
    
    cv2.imshow('BodyPix2', masked_image)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[100], line 6
#       4 # loop through frame
#       5 while cap.isOpened():
# ----> 6     ret, frame = cap.read()
#       8     result = bodypix_model.predict_single(frame)
#       9     mask = result.get_mask(threshold=0.4).numpy().astype(np.uint8)
#
# KeyboardInterrupt:

# %%
img = cv2.imread('kpyl71630558938.jpg')
img = img[:480, :640, :]

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
frame.shape
# Out:
# (480, 640, 3)

# %%
plt.imshow(mask)

# %%
plt.imshow(np.where(np.add(mask, -1) == -1, 1, np.add(mask, -1)))

# %%
cap = cv2.VideoCapture(0)

while cap.isOpened(): 
    ret, frame = cap.read()
    
    result = bodypix_model.predict_single(frame)
    mask = result.get_mask(threshold=0.4).numpy().astype(np.uint8)
    masked_image = cv2.bitwise_and(frame, frame, mask=mask)
    
    neg = np.add(mask, -0)
    inverse = np.where(neg==-0, 0, neg).astype(np.uint8)
    masked_background = cv2.bitwise_and(img, img, mask=inverse)
    final = cv2.add(masked_image, masked_background)
    
    cv2.imshow('BodyPix', final)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release() # Releases webcam or capture device
cv2.destroyAllWindows() # Closes imshow frames
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 6
#       3 while cap.isOpened():
#       4     ret, frame = cap.read()
# ----> 6     result = bodypix_model.predict_single(frame)
#       7     mask = result.get_mask(threshold=0.4).numpy().astype(np.uint8)
#       8     masked_image = cv2.bitwise_and(frame, frame, mask=mask)
#
# File c:\Users\HP\Anaconda3\envs\tf24\lib\site-packages\tf_bodypix\model.py:431, in BodyPixModelWrapper.predict_single(self, image)
#     429 model_input_size = self.get_bodypix_input_size(original_size)
#     430 LOGGER.debug('model_input_size: %r', model_input_size)
# --> 431 model_input_image, padding = self.get_padded_and_resized(image, model_input_size)
#     432 LOGGER.debug(
#     433     'model_input_image: %r (%r)', model_input_image.shape, model_input_image.dtype
#     434 )
# ...

# %%
# get vid cap device
cap = cv2.VideoCapture(0) 

# loop through frame
while cap.isOpened(): 
    ret, frame = cap.read()
    
    # BodyPix Detections
    result = bodypix_model.predict_single(frame)
    mask = result.get_mask(threshold=0.5).numpy().astype(np.uint8)
    masked_image = cv2.bitwise_and(frame, frame, mask=mask)
    
    # Apply virtual background
    neg = np.add(mask, -1)
    inverse = np.where(neg==-1, 1, neg).astype(np.uint8)
    masked_background = cv2.bitwise_and(img, img, mask=inverse)
    final = cv2.add(masked_image, masked_background)
    
    # Show result to user on desktop
    cv2.imshow('BodyPix3', final)
    
    # Break loop outcome 
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release() # Releases webcam or capture device
cv2.destroyAllWindows() # Closes imshow frames
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[96], line 9
#       6 ret, frame = cap.read()
#       8 # BodyPix Detections
# ----> 9 result = bodypix_model.predict_single(frame)
#      10 mask = result.get_mask(threshold=0.5).numpy().astype(np.uint8)
#      11 masked_image = cv2.bitwise_and(frame, frame, mask=mask)
#
# File c:\Users\HP\Anaconda3\envs\tf24\lib\site-packages\tf_bodypix\model.py:431, in BodyPixModelWrapper.predict_single(self, image)
#     429 model_input_size = self.get_bodypix_input_size(original_size)
#     430 LOGGER.debug('model_input_size: %r', model_input_size)
# --> 431 model_input_image, padding = self.get_padded_and_resized(image, model_input_size)
#     432 LOGGER.debug(
#     433     'model_input_image: %r (%r)', model_input_image.shape, model_input_image.dtype
#     434 )
#     435 LOGGER.debug('predict_fn: %r', self.predict_fn)
#
# ...
